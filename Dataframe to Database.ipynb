# %%
from functions import *
import psycopg2
import sqlalchemy

# %%
moviesData = crawlData()
moviesData
# Out:
#                                                  Name  \
# 0                                                Time
# 1                                                Dune
# 2                                        The Vanished
# 3                            Love Under House Arrest
# 4                                Occupation: Rainfall
# 5                                            Thalaivi
# 6                                            Thalaivi
# 7   Crayon Shinchan The Movie: School Mystery! The...
# 8                                           Queenpins
# 9                         The Cursed: Dead Man's Prey
# 10                                          Malignant
# 11                                             Laabam
# 12                              Escape From Mogadishu
# 13          Shang-Chi And The Legend Of The Ten Rings
# 14                                           Sinkhole
# 15                              Paw Patrol: The Movie
# ...

# %%
url = 'postgres://thwhoypafnogzl:a3f953c6eb51f1628ebd58f105128a2b13d9e7d3aa51dc756aca12dcb55a1611@ec2-3-224-7-166.compute-1.amazonaws.com:5432/d8dc5r528m6g32'

conn = psycopg2.connect(url, sslmode='require')
conn
# Out:
# <connection object at 0x000001F7DD597370; dsn: 'user=thwhoypafnogzl password=xxx dbname=d8dc5r528m6g32 host=ec2-3-224-7-166.compute-1.amazonaws.com port=5432 sslmode=require', closed: 0>

# %%
# command = (
#         '''
#         CREATE TABLE movies (
#         index INT NOT NULL,
#         name VARCHAR NOT NULL,
#         casts VARCHAR NOT NULL,
#         runtime VARCHAR NOT NULL,
#         release_date VARCHAR NOT NULL,
#         classification VARCHAR NOT NULL,
#         view_type VARCHAR NOT NULL,
#         view_status VARCHAR NOT NULL
#         )
#         '''
#         )

# command = (
#         '''
#         DROP TABLE movies
#         '''
#         )

# %%
engine = sqlalchemy.create_engine(url)

moviesData.to_sql(name='movie', con=engine, if_exists='replace')
print("end") # <- just to keep track of the process
# Out:
# end

# %%
query = "SELECT * FROM movie;"

data = getData(query, url)
print('Length of dataframe:', len(data))

data
# Out:
# Length of dataframe: 23
#     index                                               Name  \
# 0       0                                               Time
# 1       1                                               Dune
# 2       2                                       The Vanished
# 3       3                           Love Under House Arrest
# 4       4                               Occupation: Rainfall
# 5       5                                           Thalaivi
# 6       6                                           Thalaivi
# 7       7  Crayon Shinchan The Movie: School Mystery! The...
# 8       8                                          Queenpins
# 9       9                        The Cursed: Dead Man's Prey
# 10     10                                          Malignant
# 11     11                                             Laabam
# 12     12                              Escape From Mogadishu
# 13     13          Shang-Chi And The Legend Of The Ten Rings
# ...
