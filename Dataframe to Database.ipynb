# %%
from functions import *
import psycopg2

# %%
moviesData = crawlData()
moviesData
# Out:
#        ID                                       Name  \
# 0   10001                        Sridevi Soda Center
# 1   10002                      Escape From Mogadishu
# 2   10003  Shang-Chi And The Legend Of The Ten Rings
# 3   10004                      Paw Patrol: The Movie
# 4   10005                                   Sinkhole
# 5   10006                          The Forever Purge
# 6   10007                                 Bellbottom
# 7   10008                            The Night House
# 8   10009                                Raging Fire
# 9   10010                                 The Medium
# 10  10011                                   Free Guy
# 11  10012                                        Old
# 12  10013                          The Suicide Squad
# 13  10014             The Boss Baby: Family Business
# 14  10015                              Jungle Cruise
#
#                                                 Casts             Runtime  \
# 0        Sudheer Babu, Anandhi, Naresh, Satyam Rajesh  2 Hours 32 Minutes
# 1   Kim Yun-Seok, Jo In-sung, Heo Jun-Ho, Jeong Ma...    2 Hours 1 Minute
# 2   Simu Liu, Tony Leung Chiu-Wai, Awkwafina, Mich...  2 Hours 12 Minutes
# 3   Iain Armitage, Marsai Martin, Will Brisbin, Ji...   1 Hour 26 Minutes
# 4   Cha Seung-Won, Kim Sung-Kyun, Lee Kwang-Soo, K...   1 Hour 54 Minutes
# 5   Leven Rambin, Will Patton, Cassidy Freeman, An...   1 Hour 43 Minutes
# 6   Akshay Kumar, Vaani Kapoor, Huma Qureshi, Lara...   2 Hours 3 Minutes
# 7   Rebecca Hall, Sarah Goldberg, Stacy Martin, Ev...   1 Hour 47 Minutes
# 8   Donnie Yen, Nicholas Tse, Ray Lui, Qin Lan, Je...   2 Hours 6 Minutes
# 9   Narilya Gulmongkolpech, Sawanee Utoomma, Siran...  2 Hours 11 Minutes
# 10  Ryan Reynolds, Jodie Comer, Joe Keery, Lil Rel...   1 Hour 55 Minutes
# 11  Eliza Scanlen, Aaron Pierre, Alex Wolff, Vicky...   1 Hour 48 Minutes
# 12  Margot Robbie, Viola Davis, Joel Kinnaman, Jai...  2 Hours 12 Minutes
# 13  Alec Baldwin, James Marsden, Amy Sedaris, Aria...   1 Hour 47 Minutes
# 14  Dwayne Johnson, Emily Blunt, Édgar Ramírez, Ja...   2 Hours 7 Minutes
#
#     ReleaseDate Classification ViewType   ViewStatus
# 0   03 Sep 2021           NC16  Digital  Now Showing
# 1   02 Sep 2021           PG13  Digital  Now Showing
# 2   01 Sep 2021             PG  Digital  Now Showing
# 3   26 Aug 2021             PG  Digital  Now Showing
# 4   26 Aug 2021             PG  Digital  Now Showing
# 5   26 Aug 2021           NC16  Digital  Now Showing
# 6   19 Aug 2021           PG13  Digital  Now Showing
# 7   19 Aug 2021           NC16  Digital  Now Showing
# 8   19 Aug 2021           NC16  Digital  Now Showing
# 9   12 Aug 2021            M18  Digital  Now Showing
# 10  12 Aug 2021           PG13  Digital  Now Showing
# 11  12 Aug 2021           PG13  Digital  Now Showing
# 12  05 Aug 2021            M18  Digital  Now Showing
# 13  05 Aug 2021             PG  Digital  Now Showing
# 14  29 Jul 2021           PG13  Digital  Now Showing

# %%
url = 'postgres://thwhoypafnogzl:a3f953c6eb51f1628ebd58f105128a2b13d9e7d3aa51dc756aca12dcb55a1611@ec2-3-224-7-166.compute-1.amazonaws.com:5432/d8dc5r528m6g32'

conn = psycopg2.connect(url, sslmode='require')
conn
# Out:
# <connection object at 0x000001C7F81FE6A0; dsn: 'user=thwhoypafnogzl password=xxx dbname=d8dc5r528m6g32 host=ec2-3-224-7-166.compute-1.amazonaws.com port=5432 sslmode=require', closed: 0>

# %%
# command = (
#         '''
#         CREATE TABLE movies (
#         index INT NOT NULL,
#         id INT NOT NULL,
#         name VARCHAR NOT NULL,
#         casts VARCHAR NOT NULL,
#         runtime VARCHAR NOT NULL,
#         release_date VARCHAR NOT NULL,
#         classification VARCHAR NOT NULL,
#         view_type VARCHAR NOT NULL,
#         view_status VARCHAR NOT NULL
#         )
#         '''
#         )

# command = (
#         '''
#         DROP TABLE movies
#         '''
#         )

# %%
# try:
#     cur = conn.cursor()

#     # create table one by one
#     cur.execute(command)

#     # close communication with the PostgreSQL database server
#     cur.close()

#     # commit the changes
#     conn.commit()
#     conn.close()
#     print('done')

# except (Exception, psycopg2.DatabaseError) as error:
#     print(error)

# %%
import sqlalchemy

engine = sqlalchemy.create_engine('postgres://thwhoypafnogzl:a3f953c6eb51f1628ebd58f105128a2b13d9e7d3aa51dc756aca12dcb55a1611@ec2-3-224-7-166.compute-1.amazonaws.com:5432/d8dc5r528m6g32')

moviesData.to_sql(name='movie', con=engine, if_exists='append')
print("end") # <- just to keep track of the process
# Out:
# end
